# %% [markdown]
# # Week 13:  Object-oriented programming HW

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here
class Particle(object):
    def __init__(self, x, y, z, xv, yv, zv, dt, m, v):
        self.x = x
        self.y = y
        self.z = z
        self.xv = xv
        self.yv = yv
        self.zv = zv
        self.dt = dt
        self.m = m
        self.v = np.sqrt(self.xv**2 + self.yv**2 + self.zv**2)
# your solution here
    def kinetic_energy (self):
        return (self.v)**2 * 0.5 * self.m
    def distance (self, other):
        return np.sqrt (((self.x-other.x)**2)+((self.y-other.y)**2)+((self.z-other.z)**2))
    def new_position (self, dt):
            return (((self.vx*dt) + self.x), ((self.vy*dt) + self.y), ((self.vz*dt) + self.z))
        
            

class ChargedParticle(Particle):

    def __init__(self,mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge

# %%
# write/copy code here

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (not correct physics) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-2,-2,-2) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.

# %%
class ChargedParticle(Particle):

    def __init__(self,mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
        def kinetic_energy (self):
            return (self.v)**2 * 0.5 * self.m
        def distance (self, other):
            return np.sqrt (((self.x-other.x)**2)+((self.y-other.y)**2)+((self.z-other.z)**2))
            
            if distance(self, other) < 0.25:
                if self.charge > 0 and other.charge < 0 or self.charge < 0 and other.charge > 0:
                    self.vx = 0
                    self.vy = 0
                    self.vz = 0
                    other.vx = 0
                    other.vy = 0
                    other.vz = 0
                    print ("merge")
                else:
                    new_self.vx = self.vx * -1 * (self.charge + other.charge) * (self.mass/other.mass)
                    new_self.vz = self.vz * -1 * (self.charge + other.charge) * (self.mass/other.mass)
                    new_self.vy = self.vy * -1 * (self.charge + other.charge) * (self.mass/other.mass)
                    new_other.vx = other.vx * -1 * (self.charge + other.charge) * (self.mass/other.mass)
                    new_other.vy = other.vx * -1 * (self.charge + other.charge) * (self.mass/other.mass)
                    new_other.vz = other.vx * -1 * (self.charge + other.charge) * (self.mass/other.mass)

# %%
P1 = ChargedParticle(7,-5,-5,-5,1,1,1,0.5)
P2 = ChargedParticle(7,5,5,5,-1,-1,-1,-0.5)
P3 = ChargedParticle(7,5,5,5,2,2,2,0.5)
P4 = ChargedParticle(7,5,5,5,-2,-2,-2,2)
for dt in np.arange(0,25,0.5):
    P2.new_position(dt)
    P3.new_position(dt)
    print( P1.x,P1.y,P1.z)
    print(P3.x,P2.y, P3.z)
    print(P1.vx,P1.vy,P1.vz)
    print(P3.vx,P3.vy,P2.vz)
    P3.new_position(dt)
    P4.new_position(dt)
    print(P3.x,P3.y,P3.z)
    print(P4.x,P4.y,P4.z)
    print(P3.vx,P3.vy,P3.vz)
    print(P4.vx,P4.vy,P4.vz)
# Out:
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
# -5 -5 -5
# 5 5 5
# 1 1 1
# 2 2 -1
# 5 5 5
# 5 5 5
# 2 2 2
# -2 -2 -2
